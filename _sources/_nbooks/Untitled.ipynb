# %%
from rkd.didactic import *

# %%
rx,ry,rz,theta,alpha = symbols("r_x,r_y,r_z,\\theta,\\alpha", real=True)
L1,L2 = symbols("L_1, L_2")

r = Matrix([rx,ry,rz])
R = rotz(theta)*rotx(alpha)
R
# Out:
# ⎡cos(\theta)  -sin(\theta)⋅cos(\alpha)  sin(\alpha)⋅sin(\theta) ⎤
# ⎢                                                               ⎥
# ⎢sin(\theta)  cos(\alpha)⋅cos(\theta)   -sin(\alpha)⋅cos(\theta)⎥
# ⎢                                                               ⎥
# ⎣     0             sin(\alpha)               cos(\alpha)       ⎦

# %%
R*r, simplify( ( R*r ).norm() )
# Out:
# ⎛⎡rₓ⋅cos(\theta) - r_y⋅sin(\theta)⋅cos(\alpha) + r_z⋅sin(\alpha)⋅sin(\theta)⎤
# ⎜⎢                                                                          ⎥
# ⎜⎢rₓ⋅sin(\theta) + r_y⋅cos(\alpha)⋅cos(\theta) - r_z⋅sin(\alpha)⋅cos(\theta)⎥,
# ⎜⎢                                                                          ⎥
# ⎝⎣                    r_y⋅sin(\alpha) + r_z⋅cos(\alpha)                     ⎦
#
#     ___________________⎞
#    ╱   2      2      2 ⎟
#  ╲╱  rₓ  + r_y  + r_z  ⎟
#                        ⎟
#                        ⎠

# %%
RBA = rotx(pi/2)*rotz(pi/3)
RCA = roty(pi/2)*rotx(pi/2)
RCA
# Out:
# ⎡0   1  0 ⎤
# ⎢         ⎥
# ⎢0   0  -1⎥
# ⎢         ⎥
# ⎣-1  0  0 ⎦

# %%
simplify( dh(L1,0,0,t1)*dh(L2,0,0,t2) )
# Out:
# ⎡cos(\theta₁ + \theta₂)  -sin(\theta₁ + \theta₂)  0  L₁⋅cos(\theta₁) + L₂⋅cos(
# ⎢
# ⎢sin(\theta₁ + \theta₂)  cos(\theta₁ + \theta₂)   0  L₁⋅sin(\theta₁) + L₂⋅sin(
# ⎢
# ⎢          0                        0             1                       0
# ⎢
# ⎣          0                        0             0                       1
#
# \theta₁ + \theta₂)⎤
#                   ⎥
# \theta₁ + \theta₂)⎥
#                   ⎥
#                   ⎥
#                   ⎥
#                   ⎦
