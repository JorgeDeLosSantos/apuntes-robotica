# %%
from moro import *

# %%
R = rotx(q1)
R
# Out:
# ⎡1     0        0    ⎤
# ⎢                    ⎥
# ⎢0  cos(q₁)  -sin(q₁)⎥
# ⎢                    ⎥
# ⎣0  sin(q₁)  cos(q₁) ⎦

# %%
R.diff()
# Out:
# ⎡0       0            0     ⎤
# ⎢                           ⎥
# ⎢0  -sin(q₁)⋅q₁̇  -cos(q₁)⋅q₁̇⎥
# ⎢                           ⎥
# ⎣0  cos(q₁)⋅q₁̇   -sin(q₁)⋅q₁̇⎦

# %%
skew((q1p,q2p,q3p)) * R
# Out:
# ⎡ 0   sin(q₁)⋅q₂̇ - cos(q₁)⋅q₃̇  sin(q₁)⋅q₃̇ + cos(q₁)⋅q₂̇⎤
# ⎢                                                     ⎥
# ⎢q₃̇         -sin(q₁)⋅q₁̇              -cos(q₁)⋅q₁̇      ⎥
# ⎢                                                     ⎥
# ⎣-q₂̇        cos(q₁)⋅q₁̇               -sin(q₁)⋅q₁̇      ⎦

# %%
R * skew((q1p,q2p,q3p))
# Out:
# ⎡           0                 -q₃̇          q₂̇     ⎤
# ⎢                                                 ⎥
# ⎢sin(q₁)⋅q₂̇ + cos(q₁)⋅q₃̇  -sin(q₁)⋅q₁̇  -cos(q₁)⋅q₁̇⎥
# ⎢                                                 ⎥
# ⎣sin(q₁)⋅q₃̇ - cos(q₁)⋅q₂̇  cos(q₁)⋅q₁̇   -sin(q₁)⋅q₁̇⎦

# %%
simplify( R.diff() * R.T )
# Out:
# ⎡0  0    0 ⎤
# ⎢          ⎥
# ⎢0  0   -q₁̇⎥
# ⎢          ⎥
# ⎣0  q₁̇   0 ⎦
