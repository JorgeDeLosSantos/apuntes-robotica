# %%
from sympy import *
from moro import *

# %% [markdown]
# ## Manipulador RRP

# %%
RRP = Robot((60,pi/2,280,q1), (0,pi/2,0,q2), (0,0,q3,0,"p"))

# %%
T = RRP.T

# %%
re = T[:3,3]
ve = re.diff(t)
re, ve.expand()
# Out:
# ⎛⎡(q₃⋅sin(q₂) + 60)⋅cos(q₁)⎤  ⎡-q₃⋅sin(q₁)⋅sin(q₂)⋅q₁̇ + q₃⋅cos(q₁)⋅cos(q₂)⋅q₂
# ⎜⎢                         ⎥  ⎢
# ⎜⎢(q₃⋅sin(q₂) + 60)⋅sin(q₁)⎥, ⎢q₃⋅sin(q₁)⋅cos(q₂)⋅q₂̇ + q₃⋅sin(q₂)⋅cos(q₁)⋅q₁̇
# ⎜⎢                         ⎥  ⎢
# ⎝⎣    -q₃⋅cos(q₂) + 280    ⎦  ⎣                            q₃⋅sin(q₂)⋅q₂̇ - co
#
# ̇ - 60⋅sin(q₁)⋅q₁̇ + sin(q₂)⋅cos(q₁)⋅q₃̇⎤⎞
#                                     ⎥⎟
#  + sin(q₁)⋅sin(q₂)⋅q₃̇ + 60⋅cos(q₁)⋅q₁̇ ⎥⎟
#                                     ⎥⎟
# s(q₂)⋅q₃̇                             ⎦⎠

# %%
num_vals = {
    q1: pi/4,
    q2: pi/6,
    q3: 200,
    q1p: 1.5,
    q2p: 2.0,
    q3p: 30,
}

# %%
ve.subs(num_vals).evalf(6)
# Out:
# ⎡85.8499⎤
# ⎢       ⎥
# ⎢425.261⎥
# ⎢       ⎥
# ⎣174.019⎦
