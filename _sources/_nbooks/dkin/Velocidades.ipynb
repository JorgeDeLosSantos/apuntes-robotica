# %%
from moro import *

# %%
RR = Robot((l1,0,0,q1), (l2,0,0,q2))

# %%
RR.T
# Out:
# ⎡cos(q₁ + q₂)  -sin(q₁ + q₂)  0  l₁⋅cos(q₁) + l₂⋅cos(q₁ + q₂)⎤
# ⎢                                                            ⎥
# ⎢sin(q₁ + q₂)  cos(q₁ + q₂)   0  l₁⋅sin(q₁) + l₂⋅sin(q₁ + q₂)⎥
# ⎢                                                            ⎥
# ⎢     0              0        1               0              ⎥
# ⎢                                                            ⎥
# ⎣     0              0        0               1              ⎦

# %%
r = RR.T[0:3,3]
r
# Out:
# ⎡l₁⋅cos(q₁) + l₂⋅cos(q₁ + q₂)⎤
# ⎢                            ⎥
# ⎢l₁⋅sin(q₁) + l₂⋅sin(q₁ + q₂)⎥
# ⎢                            ⎥
# ⎣             0              ⎦

# %%
c1,s1 = symbols("c_1,s_1")
c12,s12 = symbols("c_{12},s_{12}")
susti = {cos(q1):c1, sin(q1):s1, cos(q1+q2):c12, sin(q1+q2):s12}

r.diff(t).subs(sustiti)
# Out:
# ⎡-l₁⋅s₁⋅q₁̇ - l₂⋅s_{12}⋅(q₁̇ + q₂̇)⎤
# ⎢                               ⎥
# ⎢c₁⋅l₁⋅q₁̇ + c_{12}⋅l₂⋅(q₁̇ + q₂̇) ⎥
# ⎢                               ⎥
# ⎣               0               ⎦
