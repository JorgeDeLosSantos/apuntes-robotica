# %%
from moro import *
from sympy import diag
# Out:
# g:\mi unidad\numython-rd\proyectos\moro\moro\moro\core.py:56: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.joint_types[-1] is "r":

# %%
PR = Robot((0,pi/2,q1,pi,"p"), (l2,0,0,q2))

# %%
PR.set_cm_locations([[0,0,0], [-(l2-lc2),0,0]])
PR.set_gravity_vector([-g,0,0])
PR.set_inertia_tensors()
PR.set_masses([m1,m2])

# %%
PR.I_ii(2)
# Out:
# ⎡I_{xx2}     0        0   ⎤
# ⎢                         ⎥
# ⎢   0     I_{yy2}     0   ⎥
# ⎢                         ⎥
# ⎣   0        0     I_{zz2}⎦

# %%
PR.get_inertia_matrix()
# Out:
# ⎡    m₁ + m₂       l_c2⋅m₂⋅cos(q₂)  ⎤
# ⎢                                   ⎥
# ⎢                               2   ⎥
# ⎣l_c2⋅m₂⋅cos(q₂)  I_{zz1} + l_c2 ⋅m₂⎦

# %%
PR.get_coriolis_matrix()
# Out:
# ⎡0  -l_c2⋅m₂⋅sin(q₂)⋅q₂̇⎤
# ⎢                      ⎥
# ⎣0           0         ⎦

# %%
PR.get_dynamic_model()
# Out:
# ⎡           ⎛                 2                       ⎞
# ⎣m₁⋅q₁̈ + m₂⋅⎝- l_c2⋅sin(q₂)⋅q₂̇  + l_c2⋅cos(q₂)⋅q₂̈ + q₁̈⎠ = τ₁, I_{zz2}⋅q₂̈
#
#                      2                                ⎤
# + g⋅l_c2⋅m₂⋅sin(q₂) + l_c2 ⋅m₂⋅q₂̈ + l_c2⋅m₂⋅cos(q₂)⋅q₁̈ = τ₂⎦

# %%
PR.get_gravity_torque_vector()
# Out:
# ⎡        0        ⎤
# ⎢                 ⎥
# ⎣g⋅l_c2⋅m₂⋅sin(q₂)⎦

# %%
PR.get_dynamic_model_matrix_form()
# Out:
# ⎡    m₁ + m₂       l_c2⋅m₂⋅cos(q₂)  ⎤
# ⎢                                   ⎥ ⎡q₁̈⎤   ⎡0  -l_c2⋅m₂⋅sin(q₂)⋅q₂̇⎤ ⎡q₁̇⎤
# ⎢                               2   ⎥⋅⎢  ⎥ + ⎢                      ⎥⋅⎢  ⎥ + ⎢
# ⎣l_c2⋅m₂⋅cos(q₂)  I_{zz1} + l_c2 ⋅m₂⎦ ⎣q₂̈⎦   ⎣0           0         ⎦ ⎣q₂̇⎦
#
#
#   ⎡        0        ⎤   ⎡τ₁⎤
#                  ⎥ = ⎢  ⎥
#  ⎣g⋅l_c2⋅m₂⋅sin(q₂)⎦   ⎣τ₂⎦

# %%
# %matplotlib notebook
PR.plot_diagram({q1:100, q2:pi/3, l2:200})
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
