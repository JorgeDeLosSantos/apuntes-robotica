# %%
from moro import *

# %%
RR = Robot((l1,0,0,q1), (l2,0,0,q2))

# %%
RR.set_cm_locations([[-(l1-lc1),0,0], [-(l2-lc2),0,0]])
RR.set_gravity_vector([0,-g,0])
RR.set_inertia_tensors()
RR.set_masses([m1,m2])

# %%
RR.get_dynamic_model_matrix_form()
# Out:
# ⎡              2                                 2          2
# ⎢2⋅I_{zz1} + l₁ ⋅m₂ + 2⋅l₁⋅l_c2⋅m₂⋅cos(q₂) + l_c1 ⋅m₁ + l_c2 ⋅m₂  I_{zz1} + l₁
# ⎢
# ⎢                                               2
# ⎣            I_{zz1} + l₁⋅l_c2⋅m₂⋅cos(q₂) + l_c2 ⋅m₂                        I_
#
#                        2   ⎤
# ⋅l_c2⋅m₂⋅cos(q₂) + l_c2 ⋅m₂⎥ ⎡q₁̈⎤   ⎡-l₁⋅l_c2⋅m₂⋅sin(q₂)⋅q₂̇  -l₁⋅l_c2⋅m₂⋅sin
#                            ⎥⋅⎢  ⎥ + ⎢
#             2              ⎥ ⎣q₂̈⎦   ⎣l₁⋅l_c2⋅m₂⋅sin(q₂)⋅q₁̇
# {zz1} + l_c2 ⋅m₂           ⎦
#
#
# (q₂)⋅q₁̇ - l₁⋅l_c2⋅m₂⋅sin(q₂)⋅q₂̇⎤ ⎡q₁̇⎤   ⎡g⋅l_c1⋅m₁⋅cos(q₁) + g⋅m₂⋅(l₁⋅cos(q
#                              ⎥⋅⎢  ⎥ + ⎢
#        0                       ⎦ ⎣q₂̇⎦   ⎣                 g⋅l_c2⋅m₂⋅cos(q₁ +
#
#
#
# ₁) + l_c2⋅cos(q₁ + q₂))⎤   ⎡τ₁⎤
#                   ⎥ = ⎢  ⎥
# q₂)                  ⎦   ⎣τ₂⎦

# %%
RR.plot_diagram({q1:pi/2, q2:pi/4, l1:200, l2:200})
