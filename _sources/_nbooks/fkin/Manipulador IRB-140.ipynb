# %%
from moro import *

# %%
IRB140 = Robot((70,pi/2,352,q1), (360,0,0,q2), (0,pi/2,0,q3), (0,-pi/2,380,q4), (0,pi/2,0,q5), (0,0,65,q6))

# %%
IRB140.T_ij(1,0)
# Out:
# ⎡cos(q₁)  0  sin(q₁)   70⋅cos(q₁)⎤
# ⎢                                ⎥
# ⎢sin(q₁)  0  -cos(q₁)  70⋅sin(q₁)⎥
# ⎢                                ⎥
# ⎢   0     1     0         352    ⎥
# ⎢                                ⎥
# ⎣   0     0     0          1     ⎦

# %%
IRB140.T_ij(2,1)
# Out:
# ⎡cos(q₂)  -sin(q₂)  0  360⋅cos(q₂)⎤
# ⎢                                 ⎥
# ⎢sin(q₂)  cos(q₂)   0  360⋅sin(q₂)⎥
# ⎢                                 ⎥
# ⎢   0        0      1       0     ⎥
# ⎢                                 ⎥
# ⎣   0        0      0       1     ⎦

# %%
IRB140.T_ij(3,2)
# Out:
# ⎡cos(q₃)  0  sin(q₃)   0⎤
# ⎢                       ⎥
# ⎢sin(q₃)  0  -cos(q₃)  0⎥
# ⎢                       ⎥
# ⎢   0     1     0      0⎥
# ⎢                       ⎥
# ⎣   0     0     0      1⎦

# %%
IRB140.T_ij(4,3)
# Out:
# ⎡cos(q₄)  0   -sin(q₄)   0 ⎤
# ⎢                          ⎥
# ⎢sin(q₄)  0   cos(q₄)    0 ⎥
# ⎢                          ⎥
# ⎢   0     -1     0      380⎥
# ⎢                          ⎥
# ⎣   0     0      0       1 ⎦

# %%
IRB140.T_ij(5,4)
# Out:
# ⎡cos(q₅)  0  sin(q₅)   0⎤
# ⎢                       ⎥
# ⎢sin(q₅)  0  -cos(q₅)  0⎥
# ⎢                       ⎥
# ⎢   0     1     0      0⎥
# ⎢                       ⎥
# ⎣   0     0     0      1⎦

# %%
IRB140.T_ij(6,5)
# Out:
# ⎡cos(q₆)  -sin(q₆)  0  0 ⎤
# ⎢                        ⎥
# ⎢sin(q₆)  cos(q₆)   0  0 ⎥
# ⎢                        ⎥
# ⎢   0        0      1  65⎥
# ⎢                        ⎥
# ⎣   0        0      0  1 ⎦

# %%
T = IRB140.T

# %%
s1,c1 = symbols("s_1,c_1")
s2,c2 = symbols("s_2,c_2")
s3,c3 = symbols("s_3,c_3")
s4,c4 = symbols("s_4,c_4")
s5,c5 = symbols("s_5,c_5")
s6,c6 = symbols("s_6,c_6")
s23,c23 = symbols("s_{23},c_{23}")

susti = {sin(q1):s1, cos(q1):c1,
         sin(q2):s2, cos(q2):c2,
         sin(q3):s3, cos(q3):c3,
         sin(q4):s4, cos(q4):c4,
         sin(q5):s5, cos(q5):c5,
         sin(q6):s6, cos(q6):c6,
         sin(q2+q3):s23, cos(q2+q3):c23,
        }

# %%
T.subs(susti)
# Out:
# ⎡c₆⋅(-c₁⋅s₅⋅s_{23} + c₅⋅(c₁⋅c₄⋅c_{23} + s₁⋅s₄)) + s₆⋅(-c₁⋅c_{23}⋅s₄ + c₄⋅s₁)
# ⎢
# ⎢c₆⋅(c₅⋅(-c₁⋅s₄ + c₄⋅c_{23}⋅s₁) - s₁⋅s₅⋅s_{23}) - s₆⋅(c₁⋅c₄ + c_{23}⋅s₁⋅s₄)
# ⎢
# ⎢               c₆⋅(c₄⋅c₅⋅s_{23} + c_{23}⋅s₅) - s₄⋅s₆⋅s_{23}
# ⎢
# ⎣                                     0
#
# c₆⋅(-c₁⋅c_{23}⋅s₄ + c₄⋅s₁) + s₆⋅(c₁⋅s₅⋅s_{23} - c₅⋅(c₁⋅c₄⋅c_{23} + s₁⋅s₄))  c₁
#
# -c₆⋅(c₁⋅c₄ + c_{23}⋅s₁⋅s₄) + s₆⋅(c₅⋅(c₁⋅s₄ - c₄⋅c_{23}⋅s₁) + s₁⋅s₅⋅s_{23})  c₅
#
#               -c₆⋅s₄⋅s_{23} - s₆⋅(c₄⋅c₅⋅s_{23} + c_{23}⋅s₅)
#
#                                     0
#
# ⋅c₅⋅s_{23} + s₅⋅(c₁⋅c₄⋅c_{23} + s₁⋅s₄)   360⋅c₁⋅c₂ + 65⋅c₁⋅c₄⋅c_{23}⋅s₅ + 65⋅c
#
# ⋅s₁⋅s_{23} + s₅⋅(-c₁⋅s₄ + c₄⋅c_{23}⋅s₁)  -65⋅c₁⋅s₄⋅s₅ + 360⋅c₂⋅s₁ + 65⋅c₄⋅c_{2
#
#       c₄⋅s₅⋅s_{23} - c₅⋅c_{23}                         65⋅c₄⋅s₅⋅s_{23} - 65⋅c₅
#
#                   0
#
# ₁⋅c₅⋅s_{23} + 380⋅c₁⋅s_{23} + 70⋅c₁ + 65⋅s₁⋅s₄⋅s₅ ⎤
#                                                   ⎥
# 3}⋅s₁⋅s₅ + 65⋅c₅⋅s₁⋅s_{23} + 380⋅s₁⋅s_{23} + 70⋅s₁⎥
#                                                   ⎥
# ⋅c_{23} - 380⋅c_{23} + 360⋅s₂ + 352               ⎥
#                                                   ⎥
#       1                                           ⎦
