# %%
from moro import *

# %%
H = htmtra([10,0,5]) * htmrot(pi) * htmrot(pi/2,"x")
H
# Out:
# ⎡-1  0  0  10⎤
# ⎢            ⎥
# ⎢0   0  1  0 ⎥
# ⎢            ⎥
# ⎢0   1  0  5 ⎥
# ⎢            ⎥
# ⎣0   0  0  1 ⎦
