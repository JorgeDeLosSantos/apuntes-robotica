# %%
from moro import *

# %%
Rx = lambda x: rotx(x)
Ry = lambda x: roty(x)
Rz = lambda x: rotz(x)

# %%
Rx(pi/2) * Ry(-pi/2)
# Out:
# ⎡0   0  -1⎤
# ⎢         ⎥
# ⎢-1  0  0 ⎥
# ⎢         ⎥
# ⎣0   1  0 ⎦

# %%
Rz(pi/3) * Rx(3*pi/4) * Rz(pi/2)
# Out:
# ⎡ √6          √6 ⎤
# ⎢ ──   -1/2   ── ⎥
# ⎢ 4           4  ⎥
# ⎢                ⎥
# ⎢-√2   -√3   -√2 ⎥
# ⎢────  ────  ────⎥
# ⎢ 4     2     4  ⎥
# ⎢                ⎥
# ⎢ √2         -√2 ⎥
# ⎢ ──    0    ────⎥
# ⎣ 2           2  ⎦
