# %%
from moro import *

# %% [markdown]
# ## Ejemplo 1

# %%
eul2htm(pi/2,pi/2,-pi/6)[:3,:3]
# Out:
# ⎡ 0     0   1⎤
# ⎢            ⎥
# ⎢ √3         ⎥
# ⎢ ──   1/2  0⎥
# ⎢ 2          ⎥
# ⎢            ⎥
# ⎢      √3    ⎥
# ⎢-1/2  ──   0⎥
# ⎣      2     ⎦

# %% [markdown]
# ## Ejemplo 2

# %%
eul2htm(0,0,pi/9).evalf(4)[:3,:3]
# Out:
# ⎡0.9397  -0.342   0 ⎤
# ⎢                   ⎥
# ⎢0.342   0.9397   0 ⎥
# ⎢                   ⎥
# ⎣  0       0     1.0⎦

# %% [markdown]
# ## Ejemplo 3

# %%
rotz(pi/3) * roty(3*pi/4)
# Out:
# ⎡-√2   -√3    √2 ⎤
# ⎢────  ────   ── ⎥
# ⎢ 4     2     4  ⎥
# ⎢                ⎥
# ⎢-√6          √6 ⎥
# ⎢────  1/2    ── ⎥
# ⎢ 4           4  ⎥
# ⎢                ⎥
# ⎢-√2         -√2 ⎥
# ⎢────   0    ────⎥
# ⎣ 2           2  ⎦

# %%
htm2eul(rotz(pi/3) * roty(3*pi/4), deg=True)
# Out:
# (150.0, 135.0, -90.0)
