# %%
from moro import *

# %%
Rzxz = rotz(phi)*rotx(theta)*rotz(psi)
Rzxz
# Out:
# ⎡-sin(φ)⋅sin(ψ)⋅cos(θ) + cos(φ)⋅cos(ψ)  -sin(φ)⋅cos(ψ)⋅cos(θ) - sin(ψ)⋅cos(φ)
# ⎢
# ⎢sin(φ)⋅cos(ψ) + sin(ψ)⋅cos(φ)⋅cos(θ)   -sin(φ)⋅sin(ψ) + cos(φ)⋅cos(ψ)⋅cos(θ)
# ⎢
# ⎣            sin(ψ)⋅sin(θ)                          sin(θ)⋅cos(ψ)
#
#  sin(φ)⋅sin(θ) ⎤
#                ⎥
#  -sin(θ)⋅cos(φ)⎥
#                ⎥
#      cos(θ)    ⎦

# %%
simplify(Rzxz.subs({theta:pi}))
# Out:
# ⎡cos(φ - ψ)  sin(φ - ψ)   0 ⎤
# ⎢                           ⎥
# ⎢sin(φ - ψ)  -cos(φ - ψ)  0 ⎥
# ⎢                           ⎥
# ⎣    0            0       -1⎦

# %%
eul2htm(0,pi,-pi/2)[:3,:3]
# Out:
# ⎡0  1  0 ⎤
# ⎢        ⎥
# ⎢1  0  0 ⎥
# ⎢        ⎥
# ⎣0  0  -1⎦
