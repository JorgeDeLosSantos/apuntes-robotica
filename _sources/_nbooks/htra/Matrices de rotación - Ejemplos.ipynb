# %%
from moro import *
from sympy import *

# %%
Rx = lambda x: rotx(x)
Ry = lambda x: roty(x)
Rz = lambda x: rotz(x)

# %% [markdown]
# ## Ejemplo 1

# %% [markdown]
# A continuación se muestra una matriz de rotación $R$, compruebe que sus columnas son mutuamente ortogonales.

# %%
R = rotx(pi/4)
R.evalf()
# Out:
# ⎡1.0          0                  0         ⎤
# ⎢                                          ⎥
# ⎢ 0   0.707106781186548  -0.707106781186548⎥
# ⎢                                          ⎥
# ⎣ 0   0.707106781186548  0.707106781186548 ⎦

# %%
( sqrt(2)/2 )**2
# Out:
# 1/2

# %% [markdown]
# ## Ejemplo composición

# %% [markdown]
# Un sistema $\{1\}$ se obtiene a partir de un sistema $\{0\}$ mediante la siguiente secuencia de rotaciones con respecto al sistema móvil: una rotación de 45° con respecto al eje $y$, seguida de una rotación alrededor del eje $z$ de 60°. Determine $R_1^0$.

# %%
Ry(pi/4) * Rz(pi/3)
# Out:
# ⎡ √2   -√6   √2⎤
# ⎢ ──   ────  ──⎥
# ⎢ 4     4    2 ⎥
# ⎢              ⎥
# ⎢ √3           ⎥
# ⎢ ──   1/2   0 ⎥
# ⎢ 2            ⎥
# ⎢              ⎥
# ⎢-√2    √6   √2⎥
# ⎢────   ──   ──⎥
# ⎣ 4     4    2 ⎦

# %% [markdown]
# ## Ejemplo composición

# %%
R10 = Rx(pi/2)
R21 = Rz(pi/3).evalf(4)
R32 = Ry(pi/4).evalf(4)

R32
# Out:
# ⎡0.7071    0   0.7071⎤
# ⎢                    ⎥
# ⎢   0     1.0    0   ⎥
# ⎢                    ⎥
# ⎣-0.7071   0   0.7071⎦

# %%
R10*R21*R32
# Out:
# ⎡0.3536  -0.866  0.3536 ⎤
# ⎢                       ⎥
# ⎢0.7071    0     -0.7071⎥
# ⎢                       ⎥
# ⎣0.6124   0.5    0.6124 ⎦
