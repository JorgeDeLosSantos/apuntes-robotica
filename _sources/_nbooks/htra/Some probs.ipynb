# %%
from moro import *

# %%
a,b,c,d,e,f,g,h,i = symbols("a:i")
R10_ = Matrix([[1,0,0],[0,a,b],[0,c,d]])
R10 = rotx(pi/3)
R21 = rotz(pi/2)*roty(pi/2)
R20_ = R10_ * R21
R20 = R10 * R21

# %%
R10, R10_, R21, R20_, R20
# Out:
# ⎛⎡1   0    0  ⎤                                       ⎡ 0    -1   0 ⎤⎞
# ⎜⎢            ⎥                                       ⎢             ⎥⎟
# ⎜⎢        -√3 ⎥  ⎡1  0  0⎤  ⎡0   -1  0⎤  ⎡0   -1  0⎤  ⎢ √3          ⎥⎟
# ⎜⎢0  1/2  ────⎥  ⎢       ⎥  ⎢         ⎥  ⎢         ⎥  ⎢ ──   0   1/2⎥⎟
# ⎜⎢         2  ⎥, ⎢0  a  b⎥, ⎢0   0   1⎥, ⎢-b  0   a⎥, ⎢ 2           ⎥⎟
# ⎜⎢            ⎥  ⎢       ⎥  ⎢         ⎥  ⎢         ⎥  ⎢             ⎥⎟
# ⎜⎢   √3       ⎥  ⎣0  c  d⎦  ⎣-1  0   0⎦  ⎣-d  0   c⎦  ⎢          √3 ⎥⎟
# ⎜⎢0  ──   1/2 ⎥                                       ⎢-1/2  0   ── ⎥⎟
# ⎝⎣   2        ⎦                                       ⎣          2  ⎦⎠

# %%
simplify( htmrot(t1)*htmtra([l1,0,0])*htmrot(pi/2-t1) )
# Out:
# ⎡0  -1  0  l₁⋅cos(\theta₁)⎤
# ⎢                         ⎥
# ⎢1  0   0  l₁⋅sin(\theta₁)⎥
# ⎢                         ⎥
# ⎢0  0   1         0       ⎥
# ⎢                         ⎥
# ⎣0  0   0         1       ⎦

# %%
htmrot(t1+pi/2)*htmrot(pi/2,"x")
# Out:
# ⎡-sin(\theta₁)  0  cos(\theta₁)  0⎤
# ⎢                                 ⎥
# ⎢cos(\theta₁)   0  sin(\theta₁)  0⎥
# ⎢                                 ⎥
# ⎢      0        1       0        0⎥
# ⎢                                 ⎥
# ⎣      0        0       0        1⎦
