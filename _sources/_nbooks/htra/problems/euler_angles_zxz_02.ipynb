# %%
from moro import *

# %%
R = Matrix([[0,0,-1],[-1,0,0],[0,1,0]])
R
# Out:
# ⎡0   0  -1⎤
# ⎢         ⎥
# ⎢-1  0  0 ⎥
# ⎢         ⎥
# ⎣0   1  0 ⎦

# %%
rot2eul(R, deg=True)
# Out:
# [(-90.0, 90.0, 0), (90.0, -90.0, 180.0)]
