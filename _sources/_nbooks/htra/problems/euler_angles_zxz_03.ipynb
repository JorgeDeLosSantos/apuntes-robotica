# %%
from moro import *

# %%
R = rotz(-2*pi/3)*rotx(pi/2)*rotz(pi/3)
R
# Out:
# ⎡      √3   -√3 ⎤
# ⎢-1/4  ──   ────⎥
# ⎢      4     2  ⎥
# ⎢               ⎥
# ⎢-√3            ⎥
# ⎢────  3/4  1/2 ⎥
# ⎢ 4             ⎥
# ⎢               ⎥
# ⎢ √3            ⎥
# ⎢ ──   1/2   0  ⎥
# ⎣ 2             ⎦

# %%
rot2eul(R, deg=True)
# Out:
# [(-120.0, 90.0, 60.0), (60.0, -90.0, -120.0)]
