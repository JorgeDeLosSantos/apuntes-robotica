# %%
from moro import *

# %%
R = rotz(2*pi/3)
R
# Out:
# ⎡      -√3    ⎤
# ⎢-1/2  ────  0⎥
# ⎢       2     ⎥
# ⎢             ⎥
# ⎢ √3          ⎥
# ⎢ ──   -1/2  0⎥
# ⎢ 2           ⎥
# ⎢             ⎥
# ⎣ 0     0    1⎦

# %%
rot2eul(R)
# Out:
# ⎡⎛2⋅π      ⎞⎤
# ⎢⎜───, 0, 0⎟⎥
# ⎣⎝ 3       ⎠⎦
