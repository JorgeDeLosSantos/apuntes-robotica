# %%
from moro import *

# %%
eul2rot(pi/4,pi/3,3*pi/4)
# Out:
# ⎡             √6 ⎤
# ⎢-3/4  -1/4   ── ⎥
# ⎢             4  ⎥
# ⎢                ⎥
# ⎢            -√6 ⎥
# ⎢-1/4  -3/4  ────⎥
# ⎢             4  ⎥
# ⎢                ⎥
# ⎢ √6   -√6       ⎥
# ⎢ ──   ────  1/2 ⎥
# ⎣ 4     4        ⎦
