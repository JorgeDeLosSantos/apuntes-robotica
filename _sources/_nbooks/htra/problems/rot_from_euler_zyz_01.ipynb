# %%
from moro import *

# %%
eul2rot(pi/2,-pi/2,pi/6,seq="zyz")
# Out:
# ⎡      -√3     ⎤
# ⎢-1/2  ────  0 ⎥
# ⎢       2      ⎥
# ⎢              ⎥
# ⎢ 0     0    -1⎥
# ⎢              ⎥
# ⎢ √3           ⎥
# ⎢ ──   -1/2  0 ⎥
# ⎣ 2            ⎦
