# %%
from moro import *

# %%
Rx = lambda theta: htmrot(theta, "x")
Ry = lambda theta: htmrot(theta, "y")
Rz = lambda theta: htmrot(theta, "z")
Dx = lambda d: htmtra([d,0,0])
Dy = lambda d: htmtra([0,d,0])
Dz = lambda d: htmtra([0,0,d])

# %% [markdown]
# ## Ejercicio 1

# %%
R01 = rotz(pi/4) * rotx(pi/2) 
R31 = rotz(5*pi/4) * roty(pi) * rotx(pi/3) 
R20 = rotx(pi/2) * rotz(pi/2)

R30 = R01.inv() * R31
R12 = R20.inv() * R01.inv()

#R30, R30.evalf(4), R13, R13.evalf(4) #, R10, R21, R32 
#R01, R31, R20, R30, R12
R30, R12
# Out:
# ⎛⎡1   0     0  ⎤  ⎡ √2   -√2     ⎤⎞
# ⎜⎢             ⎥  ⎢ ──   ────  0 ⎥⎟
# ⎜⎢   -√3       ⎥  ⎢ 2     2      ⎥⎟
# ⎜⎢0  ────  -1/2⎥  ⎢              ⎥⎟
# ⎜⎢    2        ⎥, ⎢-√2   -√2     ⎥⎟
# ⎜⎢             ⎥  ⎢────  ────  0 ⎥⎟
# ⎜⎢         -√3 ⎥  ⎢ 2     2      ⎥⎟
# ⎜⎢0  1/2   ────⎥  ⎢              ⎥⎟
# ⎝⎣          2  ⎦  ⎣ 0     0    -1⎦⎠

# %%
rot2eul(R31, deg=True)
# Out:
# [(-135.0, 120.0, 180.0), (45.0, -120.0, 0)]
