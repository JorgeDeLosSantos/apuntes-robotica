# %%
from moro import *

# %% [markdown]
# <img src="https://jorgedelossantos.github.io/apuntes-robotica/_images/ik_6dof_robot_02.svg">

# %%
R = Robot(
    (0,pi/2,400,q1), 
    (350,0,0,q2),
    (40,pi/2,0,q3),
    (0,-pi/2,360,q4),
    (0,pi/2,0,q5),
    (0,0,80,q6)
)

# %%
T = R.T

# %%
T.subs({
    q1:0, q2:pi/2, q3:0, q4:0, q5:0, q6:0
})
# Out:
# ⎡0  0   1  440⎤
# ⎢             ⎥
# ⎢0  -1  0   0 ⎥
# ⎢             ⎥
# ⎢1  0   0  790⎥
# ⎢             ⎥
# ⎣0  0   0   1 ⎦

# %%
R.plot_diagram({
    q1:0, q2:pi/2, q3:0, q4:0, q5:0, q6:0
})
